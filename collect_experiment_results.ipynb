# %%
import os 
import glob
import pickle
import datetime as dt 
import pandas as pd 

def read_pickle( fname ) : 
    with open( fname, "rb" ) as f_in : 
        return pickle.load( f_in )
    
all_dics = []
for in_path in glob.glob( "experiment_results/exp*.pkl") :
    
    dic = read_pickle( in_path )    
    del dic["per_epoch"]
    dic["time"] = dt.datetime.fromtimestamp( os.stat( in_path ).st_mtime )
    all_dics.append( dic )
    
df = pd.DataFrame( all_dics ).sort_values( "best_valid_accy", ascending=False) 
df = df.set_index( 'md5_dig')[["best_valid_accy",  "best_valid_epoch", "netw_arch_name",
                                "learning_rate", "batch_size", "keep_prob", "time"]]
# df = pd.DataFrame( all_dics ).sort_values( "time", ascending=False) 
#df.shape
df
# Out:
#           best_valid_accy  best_valid_epoch netw_arch_name  learning_rate  \
# md5_dig
# 435d9eb8         0.975057               294     arch_3_3_b         0.0005
# 663b39b1         0.974603               270     arch_3_3_b         0.0005
# 87b6d542         0.971656               199     arch_3_3_b         0.0005
# 82ca6628         0.969842               198     arch_3_3_b         0.0005
# 34f21eb9         0.969161               134   arch_3_3_2fc         0.0005
# ff7c7367         0.968935               193   arch_3_3_2fc         0.0005
# 2f19bb9e         0.966894               173     arch_3_3_b         0.0005
# e6e2d063         0.966440               197   arch_3_3_2fc         0.0005
# 54030e3e         0.965760               185   arch_3_3_2fc         0.0010
# 4ff12385         0.965306               199     arch_3_3_b         0.0010
# a490f57a         0.964399               145   arch_3_3_2fc         0.0010
# 23eae2c1         0.963719               195     arch_3_3_b         0.0005
# 5d8aabeb         0.963719               171   arch_3_3_2fc         0.0005
# c0991c18         0.963492               156     arch_3_3_b         0.0010
# b02c52d1         0.963039               196     arch_3_3_b         0.0005
# f955ab9d         0.962585               135   arch_3_3_2fc         0.0005
# eb00d42f         0.962585               168       arch_3_3         0.0005
# 0ee117b4         0.961678               190   arch_3_3_2fc         0.0010
# 98986b5e         0.961678               174     arch_3_3_b         0.0005
# 3317ad5b         0.960771               175     arch_3_3_b         0.0005
# 881928da         0.960771               196   arch_3_3_2fc         0.0010
# ba8cc667         0.958731               187       arch_3_3         0.0005
# 1a1d93e2         0.958504               193     arch_3_3_b         0.0010
# a5ab239c         0.958504               195       arch_3_3         0.0005
# fe3c2184         0.956463               190   arch_3_3_2fc         0.0005
# eb73391a         0.955102               190     arch_3_3_b         0.0010
# 3deba9b9         0.954649               162   arch_3_3_2fc         0.0010
# 2559b2d6         0.953742               194     arch_3_3_b         0.0010
# ba549f28         0.952835               196       arch_3_3         0.0010
# 3eb42e7b         0.952381               153       arch_3_3         0.0005
# 2b5d0361         0.951474               177       arch_3_3         0.0005
# c6d23e3b         0.950794               174       arch_3_3         0.0010
# cccd6358         0.949433               186   arch_3_3_2fc         0.0010
# 51f797a7         0.948980               170       arch_3_3         0.0005
# c60d0af2         0.947393               184       arch_3_3         0.0010
# bbdeea99         0.946486               196       arch_3_3         0.0010
# f203d447         0.944671               193       arch_3_3         0.0010
# ffa988dc         0.825170               199       arch_3_3         0.0010
# decab009         0.056009                37     arch_3_3_b         0.0010
# eadf6cea         0.054875                32       arch_3_3         0.0005
#
#           batch_size  keep_prob                time
# md5_dig
# 435d9eb8         128       0.60 2018-12-30 02:05:18
# 663b39b1         256       0.65 2018-12-30 02:18:58
# 87b6d542         256       0.70 2018-12-29 23:56:00
# 82ca6628         128       0.65 2018-12-30 01:48:02
# 34f21eb9         256       0.80 2018-12-29 21:05:08
# ff7c7367         256       0.90 2018-12-29 20:56:14
# 2f19bb9e         256       0.90 2018-12-29 23:38:08
# e6e2d063         512       0.80 2018-12-29 22:02:50
# 54030e3e         256       0.70 2018-12-29 22:53:10
# 4ff12385         256       0.70 2018-12-30 01:00:39
# a490f57a         512       0.70 2018-12-29 23:17:32
# 23eae2c1         512       0.80 2018-12-30 00:11:50
# 5d8aabeb         256       0.70 2018-12-29 21:13:58
# c0991c18         512       0.70 2018-12-30 01:24:46
# b02c52d1         512       0.70 2018-12-30 00:19:45
# f955ab9d         512       0.70 2018-12-29 22:10:48
# eb00d42f         256       0.70 2018-12-29 17:13:32
# 0ee117b4         512       0.80 2018-12-29 23:09:26
# 98986b5e         512       0.90 2018-12-30 00:03:55
# 3317ad5b         256       0.80 2018-12-29 23:47:04
# 881928da         256       0.90 2018-12-29 22:19:45
# ba8cc667         512       0.90 2018-12-29 17:20:13
# 1a1d93e2         256       0.80 2018-12-30 00:51:33
# a5ab239c         512       0.80 2018-12-29 17:26:54
# fe3c2184         512       0.90 2018-12-29 21:54:52
# eb73391a         256       0.90 2018-12-30 00:28:42
# 3deba9b9         256       0.80 2018-12-29 22:28:41
# 2559b2d6         512       0.80 2018-12-30 01:16:43
# ba549f28         256       0.90 2018-12-29 17:41:26
# 3eb42e7b         256       0.90 2018-12-29 16:58:01
# 2b5d0361         512       0.70 2018-12-29 17:33:37
# c6d23e3b         512       0.80 2018-12-29 20:40:45
# cccd6358         512       0.90 2018-12-29 23:01:17
# 51f797a7         256       0.80 2018-12-29 17:05:47
# c60d0af2         256       0.80 2018-12-29 17:49:15
# bbdeea99         512       0.90 2018-12-29 20:34:06
# f203d447         256       0.70 2018-12-29 17:57:04
# ffa988dc         512       0.70 2018-12-29 20:47:22
# decab009         512       0.90 2018-12-30 01:08:41
# eadf6cea         256       0.20 2018-12-29 16:48:18
